# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("forscaling.csv")

# %%
dataset
# Out:
#    Age  Salary
# 0   25   30000
# 1   30   40000
# 2   35   50000
# 3   40   60000
# 4   45   70000

# %%
X = dataset[["Age","Salary"]]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaleddataset = scaler.fit_transform(X)

# %%
scaleddataset
# Out:
# array([[-1.41421356, -1.41421356],
#        [-0.70710678, -0.70710678],
#        [ 0.        ,  0.        ],
#        [ 0.70710678,  0.70710678],
#        [ 1.41421356,  1.41421356]])

# %%
from sklearn.preprocessing import MinMaxScaler
normscaler = MinMaxScaler()

# %%
ndataset = normscaler.fit_transform(X)

# %%
ndataset
# Out:
# array([[0.  , 0.  ],
#        [0.25, 0.25],
#        [0.5 , 0.5 ],
#        [0.75, 0.75],
#        [1.  , 1.  ]])
