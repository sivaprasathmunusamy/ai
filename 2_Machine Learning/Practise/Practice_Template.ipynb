# %% [markdown]
# # For the Give Dataset Perform Classification : Use IRIS dataset

# %%
#give the paragraph anwers in comments

# %% [markdown]
# # Step 1:Import Libraries

# %%
#Your code:

# %% [markdown]
# # Step 2 : Read the Dataset , is the dataset can be only in CSV ? what are the other formats pandas support ?and how you will read those

# %%
#Your code:



#Your answer for the question

# %% [markdown]
# # Step 3: Split the Dataset into Features and Target ? how will you split using iloc

# %%
#Your code:

# %% [markdown]
# # Step 4 : if Encoding Required ! What you will choose One hot or Label , what are the encoders avaialbale , how will you decide what encoder`1

# %%
#Your code:



#Your answer for the question

# %% [markdown]
# # Step 5 : Scale the dataset , which Scaling technique you will chooose , Why ?

# %%
#Your code:



#Your answer for the question

# %% [markdown]
# # Step 6: Split the Dataset into Training and Test Set , what ratio you need to choose and Why?

# %%
#Your code:



#Your answer for the question

# %% [markdown]
# # Step 7 : Create the Model ! What is a Model

# %%
#Your code:



#Your answer for the question

# %% [markdown]
# # Step 8 : Train the Model

# %%
#Your code:



#Your answer for the question

# %% [markdown]
# # Step 9 : Test the Model , what accuracy metric you will choose and why?

# %%
#Your code:



#Your answer for the question
